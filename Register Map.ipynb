# %%
class OV2640BitField :
    def __init__(self,name,value,desc):
        self.name = name.strip()
        self.value = value.strip()
        self.description = desc.strip()
        self.isVariable = None
        self.isParsed = False
    def hasDescription(self) :
        return self.description != None and len(self.description) > 0
    # return description or name
    def getDescription(self) :
        if self.hasDescription() :
            return self.description
        return self.name
    # return the field in a non-compilable descriptive form
    # format H)igh level, L)ow level, M)achine level
    def printField(self,decodedArg,fieldFormat) :
        if fieldFormat == "H" :
            if self.isSimpleFlag() :
                desc = '{:s}'.format(self.getDescription())
            else:
                desc = '{:s}({:d})'.format(self.getDescription(),decodedArg)
        elif fieldFormat == "L" :
            if self.isSimpleFlag() :
                desc = '{:s}'.format(self.name)
            else:
                desc = '{:s}({:d})'.format(self.name,decodedArg)
        else:
            desc = ''
            
        return desc

    #true for constant flags
    def isSimpleFlag(self) :
        return self.isVariable == False
    # returns the flag value
    def simpleFlagValue(self,progArg) :
        if ((progArg & self.value == self.value and self.value > 0) or
            (progArg == 0 and self.value == 0)):
            return self.value
        return None
    # true if the bit field is set
    def isBitField(self) :
        return self.isVariable == True
    # get the bit field value AND mask it out
    def extractBitFieldValue(self,progArg) :
        shiftmask = self.value[1] << self.value[2]
        bits = progArg & shiftmask
        downshift = self.getRegisterShift()
        bits = bits >> downshift
        bits = bits & self.value[1]
        bits << self.value[0]
        #mask the field out of the arg
        progArg = progArg & (~shiftmask)
        return [bits,progArg]
    def getRegisterShift(self):
        if self.isVariable != True:
            return None
        return self.value[2]
    def compile(self):
        if self.isParsed == False and self.value.startswith('0x'):
            self.value = int(self.value,16)
            self.isVariable = False
            self.isParsed = True
        elif self.isParsed == False and self.value.startswith('[') :
            ss = self.value[1:-1]
            ss = ss.split(',')
            ss[0] = int(ss[0],10)
            ss[1] = int(ss[1],16)
            ss[2] = int(ss[2],10)
            self.value = ss
            self.isVariable = True

# %%
class OV2640Register:
    'Defines a register on the )V2640 Sensor Array'
    reserveCounters = [0,0]
    def __init__(self,bank,name,subscript,datatype,defaultValue,address,mitTag,bitFields) :
        self.bank = bank
        if name == 'RSVD':
            c = OV2640Register.reserveCounters[self.bank]
            name = '{:s}{:02d}'.format(name,c)
            c += 1
            OV2640Register.reserveCounters[self.bank] = c
        
        self.name = name
        self.subscript = subscript
        self.datatype = datatype
        self.defaultValue = defaultValue
        self.address = address
        self.mitTag = mitTag
        self.bitFields = bitFields
    def hasDescription(self) :
        return self.mitTag != None and len(self.mitTag) > 0
    def registerName(self) :
        return 'RB{:d}_{:s}'.format(self.bank,self.name)
    
    def registerDeclaration(self) :
        return 'const uint8_t {:s} = 0x{:02x};'.format(self.registerName(),self.address)
    def cantDecodeArgument(self,progArg) :
        return '0x{:02x}'.format(progArg)
    # this will example a register value and attempt to decode it - it
    # will return any bitfields and flags it identifies and the remaining
    # bits that were not processed
    def decodeArgument(self,progArg):
        selectedFields = []      
        # if no bitfield definitions then it can't be decoded
        if(len(self.bitFields) == 0):
            return [selectedFields,progArg]
        
        # iterate over the bit fields
        for aBitField in self.bitFields :
            if aBitField.isSimpleFlag() :
                flagValue = aBitField.simpleFlagValue(progArg)
                if flagValue != None :
                    selectedFields.append([aBitField,flagValue])
                # mask the field out of the arg
                progArg = progArg & (~aBitField.value)
            elif aBitField.isBitField() :
                fieldVal,newProgArg = aBitField.extractBitFieldValue(progArg)
                selectedFields.append([aBitField,fieldVal])
                #mask the field out of the arg
                progArg = newProgArg
        return [selectedFields,progArg]
                                       
    
    def printArgument(self,decodeVector,fieldFormat) :
        summary = ''
        for decodeItem in decodeVector :
            bitField,fieldValue = decodeItem
            if len(summary) > 0:
                summary += " | "
            dtext = bitField.printField(fieldValue,fieldFormat)
            desc = ' {:s} '.format(dtext)
            summary = summary + desc
        return summary

# %%
import datetime
import time
import csv

def onesComp(value,numBits) :
    # make me a number with the requisite number of ones bits
    basis = math.pow(2,numBits) - 1;
    return basis ^ value
            
class OV2640Program:
    'Defines an ordered set of register loads for the OV2640 image sensor'
    registerSet0 = [None] * 256
    registerSet1 = [None] * 256
    @staticmethod
    def loadRegisters():
        OV2640Register.reserveCounters[0] = 0
        OV2640Register.reserveCounters[1] = 0
        firstRow = True
        with open("Register Map1.csv") as f:
            reader = csv.reader(f)
            for row in reader:
                if firstRow :
                    firstRow = False
                    continue
                address = row[0].strip()
                bank = int(row[1].strip(),10)
                name = row[2].strip()
                subscript = row[3].strip()
                default = row[4].strip()
                direction = row[5].strip()
                mitTag = ''
                bitfields = []
                optCount = len(row)
                if optCount > 6:
                    mitTag = row[6]
                    fieldIndex = 7
                    while fieldIndex < optCount and len(row[fieldIndex]) > 0:
                        bf = OV2640BitField(row[fieldIndex],row[fieldIndex + 1],row[fieldIndex + 2]);
                        bf.compile()
                        bitfields.append(bf)
                        fieldIndex += 3
                dashIndex = address.find("-")
                if dashIndex != -1 :
                    min = int(address[:dashIndex].strip(),16)
                    max = int(address[1+dashIndex:].strip(),16)
                else:
                    min = int(address,16)
                    max = min

                bracketIndex = name.find("[")
                datatype = "WORD"
                if bracketIndex != -1 :
                    bracket = name[bracketIndex:].strip()
                    datatype = types.get(bracket, bracket)
                    name = name[:bracketIndex]
                    
                for regAddr in range(min,max+1):
                    register = OV2640Register(bank,name,subscript,datatype,default,regAddr,mitTag,bitfields)
                    if bank == 0:
                        OV2640Program.registerSet0[regAddr] = register
                    else:
                        OV2640Program.registerSet1[regAddr] = register
    @staticmethod
    def printRegisters():
        for i in range(0,256):
            if OV2640Program.registerSet0[i] != None:
                print(OV2640Program.registerSet0[i].registerDeclaration())
        for i in range(0,256):
            if OV2640Program.registerSet1[i] != None:
                print(OV2640Program.registerSet1[i].registerDeclaration())
    def __init__(self) :
        self.program = []
        self.activeBank = None
        
    def describe(self,programName,fieldFormat,progFile) :
        if fieldFormat != "M" :
            print("/********************************************",file=progFile)
            print("START Program,{:s}\t\tGenerated,{:s}\t\tLevel:{:s}".format(programName,time.strftime("%c"),fieldFormat),file=progFile)
            print(file=progFile)
        else:
            print("const struct sensor_reg {:s}[] =".format(programName),file=progFile)
            print("{",file=progFile)
        fileName = programName + '.csv'
        with open(fileName) as f:
            reader = csv.reader(f)
            self.activeBank = 1
            lineCtr = 1
            for row in reader:
                if len(row) == 2 :
                    regAddr = int(row[0].strip(),16)
                    regValue = int(row[1].strip(),16)
                    assert regAddr != 255 or regValue != 255
                    self.program.append([regAddr,regValue])
                    if fieldFormat != "M":
                        progtext = self.printLine(regAddr,regValue,fieldFormat,lineCtr)
                    else:
                        progtext = "\t{:s}0x{:02x},0x{:02x}{:s},\t\t//{:03d}".format("{",regAddr,regValue,"}",lineCtr)
                    print(progtext,file=progFile)
                    lineCtr += 1
            if fieldFormat != "M" :     
                print(file=progFile)
                print("END Program,{:s}\t\tGenerated,{:s}\t\tLevel:{:s}".format(programName,time.strftime("%c"),fieldFormat),file=progFile)
                print("********************************************/",file=progFile)
            else:
                print("};",file=progFile)
                print(file=progFile)
    def printLine(self,regAddr,regValue,fieldFormat,lineCtr) :
        if regAddr == 255:
            self.activeBank = regValue
            register = OV2640Program.registerSet0[255]
        elif self.activeBank == 0:
            register = OV2640Program.registerSet0[regAddr]
        elif self.activeBank == 1:
            register = OV2640Program.registerSet1[regAddr]
        else:
            opCode = '0x{:02x}'.format(regAddr)
        if self.activeBank != None and fieldFormat != "M" :
            if fieldFormat == "H" and register.hasDescription() :
                printReg = register.mitTag
            else: 
                printReg = register.registerName();
            if(printReg == None or len(printReg) == 0) :
                printReg = '0x{:02x}'.format(regAddr)
            decodedFields,remainingbits = register.decodeArgument(regValue)
            if len(decodedFields) > 0 :
                printVal = register.printArgument(decodedFields,fieldFormat)
                if remainingbits > 0 :
                    unknownBits = ' ??{:02x}?? '.format(remainingbits)
                    printVal = printVal + unknownBits
            else:
                printVal = '0x{:02x}'.format(regValue)
        else:
            printReg = '0x{:02x}'.format(regAddr)
            printVal = '0x{:02x}'.format(regValue)
        return "{:03d}\t\t{:s}\t{:s}".format(lineCtr,printReg.ljust(40),printVal)

# %%
OV2640Program.loadRegisters()
OV2640Program.printRegisters()
programs = ['OV2640_QVGA','OV2640_JPEG_INIT','OV2640_YUV422','OV2640_JPEG','OV2640_160x120_JPEG','OV2640_176x144_JPEG',
            'OV2640_320x240_JPEG','OV2640_352x288_JPEG','OV2640_640x480_JPEG','OV2640_800x600_JPEG',
            'OV2640_1024x768_JPEG','OV2640_1280x1024_JPEG','OV2640_1600x1200_JPEG']
for aProgram in programs :
    progFile = open(aProgram + ".regpgm.cpp", "w")
    pgm = OV2640Program();
    pgm.describe(aProgram,"H",progFile)
    pgm.describe(aProgram,"L",progFile)
    pgm.describe(aProgram,"M",progFile)
    progFile.close()
# Out:
# const uint8_t RB0_RSVD00 = 0x00;
# const uint8_t RB0_RSVD01 = 0x01;
# const uint8_t RB0_RSVD02 = 0x02;
# const uint8_t RB0_RSVD03 = 0x03;
# const uint8_t RB0_RSVD04 = 0x04;
# const uint8_t RB0_R_BYPASS = 0x05;
# const uint8_t RB0_RSVD05 = 0x06;
# const uint8_t RB0_RSVD06 = 0x07;
# const uint8_t RB0_RSVD07 = 0x08;
# const uint8_t RB0_RSVD08 = 0x09;
# const uint8_t RB0_RSVD09 = 0x0a;
# const uint8_t RB0_RSVD10 = 0x0b;
# const uint8_t RB0_RSVD11 = 0x0c;
# const uint8_t RB0_RSVD12 = 0x0d;
# const uint8_t RB0_RSVD13 = 0x0e;
# const uint8_t RB0_RSVD14 = 0x0f;
# const uint8_t RB0_RSVD15 = 0x10;
# const uint8_t RB0_RSVD16 = 0x11;
# const uint8_t RB0_RSVD17 = 0x12;
# const uint8_t RB0_RSVD18 = 0x13;
# const uint8_t RB0_RSVD19 = 0x14;
# const uint8_t RB0_RSVD20 = 0x15;
# const uint8_t RB0_RSVD21 = 0x16;
# const uint8_t RB0_RSVD22 = 0x17;
# const uint8_t RB0_RSVD23 = 0x18;
# const uint8_t RB0_RSVD24 = 0x19;
# const uint8_t RB0_RSVD25 = 0x1a;
# const uint8_t RB0_RSVD26 = 0x1b;
# const uint8_t RB0_RSVD27 = 0x1c;
# const uint8_t RB0_RSVD28 = 0x1d;
# const uint8_t RB0_RSVD29 = 0x1e;
# const uint8_t RB0_RSVD30 = 0x1f;
# const uint8_t RB0_RSVD31 = 0x20;
# const uint8_t RB0_RSVD32 = 0x21;
# const uint8_t RB0_RSVD33 = 0x22;
# const uint8_t RB0_RSVD34 = 0x23;
# const uint8_t RB0_RSVD35 = 0x24;
# const uint8_t RB0_RSVD36 = 0x25;
# const uint8_t RB0_RSVD37 = 0x26;
# const uint8_t RB0_RSVD38 = 0x27;
# const uint8_t RB0_RSVD39 = 0x28;
# const uint8_t RB0_RSVD40 = 0x29;
# const uint8_t RB0_RSVD41 = 0x2a;
# const uint8_t RB0_RSVD42 = 0x2b;
# const uint8_t RB0_RSVD43 = 0x2c;
# const uint8_t RB0_RSVD44 = 0x2d;
# const uint8_t RB0_RSVD45 = 0x2e;
# const uint8_t RB0_RSVD46 = 0x2f;
# const uint8_t RB0_RSVD47 = 0x30;
# const uint8_t RB0_RSVD48 = 0x31;
# const uint8_t RB0_RSVD49 = 0x32;
# const uint8_t RB0_RSVD50 = 0x33;
# const uint8_t RB0_RSVD51 = 0x34;
# const uint8_t RB0_RSVD52 = 0x35;
# const uint8_t RB0_RSVD53 = 0x36;
# const uint8_t RB0_RSVD54 = 0x37;
# const uint8_t RB0_RSVD55 = 0x38;
# const uint8_t RB0_RSVD56 = 0x39;
# const uint8_t RB0_RSVD57 = 0x3a;
# const uint8_t RB0_RSVD58 = 0x3b;
# const uint8_t RB0_RSVD59 = 0x3c;
# const uint8_t RB0_RSVD60 = 0x3d;
# const uint8_t RB0_RSVD61 = 0x3e;
# const uint8_t RB0_RSVD62 = 0x3f;
# const uint8_t RB0_RSVD63 = 0x40;
# const uint8_t RB0_RSVD64 = 0x41;
# const uint8_t RB0_RSVD65 = 0x42;
# const uint8_t RB0_RSVD66 = 0x43;
# const uint8_t RB0_Qs = 0x44;
# const uint8_t RB0_RSVD67 = 0x45;
# const uint8_t RB0_RSVD68 = 0x46;
# const uint8_t RB0_RSVD69 = 0x47;
# const uint8_t RB0_RSVD70 = 0x48;
# const uint8_t RB0_RSVD71 = 0x49;
# const uint8_t RB0_RSVD72 = 0x4a;
# const uint8_t RB0_RSVD73 = 0x4b;
# const uint8_t RB0_RSVD74 = 0x4c;
# const uint8_t RB0_RSVD75 = 0x4d;
# const uint8_t RB0_RSVD76 = 0x4e;
# const uint8_t RB0_RSVD77 = 0x4f;
# const uint8_t RB0_CTRL = 0x50;
# const uint8_t RB0_HSIZE = 0x51;
# const uint8_t RB0_VSIZE = 0x52;
# const uint8_t RB0_XOFFL = 0x53;
# const uint8_t RB0_YOFFL = 0x54;
# const uint8_t RB0_VHYX = 0x55;
# const uint8_t RB0_DPRP = 0x56;
# const uint8_t RB0_TEST = 0x57;
# const uint8_t RB0_ZMOW = 0x5a;
# const uint8_t RB0_ZMOH = 0x5b;
# const uint8_t RB0_ZMHH = 0x5c;
# const uint8_t RB0_RSVD78 = 0x5d;
# const uint8_t RB0_RSVD79 = 0x5e;
# const uint8_t RB0_RSVD80 = 0x5f;
# const uint8_t RB0_RSVD81 = 0x60;
# const uint8_t RB0_RSVD82 = 0x61;
# const uint8_t RB0_RSVD83 = 0x62;
# const uint8_t RB0_RSVD84 = 0x63;
# const uint8_t RB0_RSVD85 = 0x64;
# const uint8_t RB0_RSVD86 = 0x65;
# const uint8_t RB0_RSVD87 = 0x66;
# const uint8_t RB0_RSVD88 = 0x67;
# const uint8_t RB0_RSVD89 = 0x68;
# const uint8_t RB0_RSVD90 = 0x69;
# const uint8_t RB0_RSVD91 = 0x6a;
# const uint8_t RB0_RSVD92 = 0x6b;
# const uint8_t RB0_RSVD93 = 0x6c;
# const uint8_t RB0_RSVD94 = 0x6d;
# const uint8_t RB0_RSVD95 = 0x6e;
# const uint8_t RB0_RSVD96 = 0x6f;
# const uint8_t RB0_RSVD97 = 0x70;
# const uint8_t RB0_RSVD98 = 0x71;
# const uint8_t RB0_RSVD99 = 0x72;
# const uint8_t RB0_RSVD100 = 0x73;
# const uint8_t RB0_RSVD101 = 0x74;
# const uint8_t RB0_RSVD102 = 0x75;
# const uint8_t RB0_RSVD103 = 0x76;
# const uint8_t RB0_RSVD104 = 0x77;
# const uint8_t RB0_RSVD105 = 0x78;
# const uint8_t RB0_RSVD106 = 0x79;
# const uint8_t RB0_RSVD107 = 0x7a;
# const uint8_t RB0_RSVD108 = 0x7b;
# const uint8_t RB0_BPADDR = 0x7c;
# const uint8_t RB0_BPDATA = 0x7d;
# const uint8_t RB0_RSVD109 = 0x7e;
# const uint8_t RB0_RSVD110 = 0x7f;
# const uint8_t RB0_RSVD111 = 0x80;
# const uint8_t RB0_RSVD112 = 0x81;
# const uint8_t RB0_RSVD113 = 0x82;
# const uint8_t RB0_RSVD114 = 0x83;
# const uint8_t RB0_RSVD115 = 0x84;
# const uint8_t RB0_RSVD116 = 0x85;
# const uint8_t RB0_CTRL2 = 0x86;
# const uint8_t RB0_CTRL3 = 0x87;
# const uint8_t RB0_RSVD117 = 0x88;
# const uint8_t RB0_RSVD118 = 0x89;
# const uint8_t RB0_RSVD119 = 0x8a;
# const uint8_t RB0_RSVD120 = 0x8b;
# const uint8_t RB0_SIZEL = 0x8c;
# const uint8_t RB0_RSVD121 = 0x8d;
# const uint8_t RB0_RSVD122 = 0x8e;
# const uint8_t RB0_RSVD123 = 0x8f;
# const uint8_t RB0_RSVD124 = 0x90;
# const uint8_t RB0_RSVD125 = 0x91;
# const uint8_t RB0_RSVD126 = 0x92;
# const uint8_t RB0_RSVD127 = 0x93;
# const uint8_t RB0_RSVD128 = 0x94;
# const uint8_t RB0_RSVD129 = 0x95;
# const uint8_t RB0_RSVD130 = 0x96;
# const uint8_t RB0_RSVD131 = 0x97;
# const uint8_t RB0_RSVD132 = 0x98;
# const uint8_t RB0_RSVD133 = 0x99;
# const uint8_t RB0_RSVD134 = 0x9a;
# const uint8_t RB0_RSVD135 = 0x9b;
# const uint8_t RB0_RSVD136 = 0x9c;
# const uint8_t RB0_RSVD137 = 0x9d;
# const uint8_t RB0_RSVD138 = 0x9e;
# const uint8_t RB0_RSVD139 = 0x9f;
# const uint8_t RB0_RSVD140 = 0xa0;
# const uint8_t RB0_RSVD141 = 0xa1;
# const uint8_t RB0_RSVD142 = 0xa2;
# const uint8_t RB0_RSVD143 = 0xa3;
# const uint8_t RB0_RSVD144 = 0xa4;
# const uint8_t RB0_RSVD145 = 0xa5;
# const uint8_t RB0_RSVD146 = 0xa6;
# const uint8_t RB0_RSVD147 = 0xa7;
# const uint8_t RB0_RSVD148 = 0xa8;
# const uint8_t RB0_RSVD149 = 0xa9;
# const uint8_t RB0_RSVD150 = 0xaa;
# const uint8_t RB0_RSVD151 = 0xab;
# const uint8_t RB0_RSVD152 = 0xac;
# const uint8_t RB0_RSVD153 = 0xad;
# const uint8_t RB0_RSVD154 = 0xae;
# const uint8_t RB0_RSVD155 = 0xaf;
# const uint8_t RB0_RSVD156 = 0xb0;
# const uint8_t RB0_RSVD157 = 0xb1;
# const uint8_t RB0_RSVD158 = 0xb2;
# const uint8_t RB0_RSVD159 = 0xb3;
# const uint8_t RB0_RSVD160 = 0xb4;
# const uint8_t RB0_RSVD161 = 0xb5;
# const uint8_t RB0_RSVD162 = 0xb6;
# const uint8_t RB0_RSVD163 = 0xb7;
# const uint8_t RB0_RSVD164 = 0xb8;
# const uint8_t RB0_RSVD165 = 0xb9;
# const uint8_t RB0_RSVD166 = 0xba;
# const uint8_t RB0_RSVD167 = 0xbb;
# const uint8_t RB0_RSVD168 = 0xbc;
# const uint8_t RB0_RSVD169 = 0xbd;
# const uint8_t RB0_RSVD170 = 0xbe;
# const uint8_t RB0_RSVD171 = 0xbf;
# const uint8_t RB0_HSIZE8 = 0xc0;
# const uint8_t RB0_VSIZE8 = 0xc1;
# const uint8_t RB0_CTRL0 = 0xc2;
# const uint8_t RB0_CTRL1 = 0xc3;
# const uint8_t RB0_RSVD172 = 0xc4;
# const uint8_t RB0_RSVD173 = 0xc5;
# const uint8_t RB0_RSVD174 = 0xc6;
# const uint8_t RB0_RSVD175 = 0xc7;
# const uint8_t RB0_RSVD176 = 0xc8;
# const uint8_t RB0_RSVD177 = 0xc9;
# const uint8_t RB0_RSVD178 = 0xca;
# const uint8_t RB0_RSVD179 = 0xcb;
# const uint8_t RB0_RSVD180 = 0xcc;
# const uint8_t RB0_RSVD181 = 0xcd;
# const uint8_t RB0_RSVD182 = 0xce;
# const uint8_t RB0_RSVD183 = 0xcf;
# const uint8_t RB0_RSVD184 = 0xd0;
# const uint8_t RB0_RSVD185 = 0xd1;
# const uint8_t RB0_RSVD186 = 0xd2;
# const uint8_t RB0_R_DVP_SP = 0xd3;
# const uint8_t RB0_RSVD187 = 0xd4;
# const uint8_t RB0_RSVD188 = 0xd5;
# const uint8_t RB0_RSVD189 = 0xd6;
# const uint8_t RB0_RSVD190 = 0xd7;
# const uint8_t RB0_RSVD191 = 0xd8;
# const uint8_t RB0_RSVD192 = 0xd9;
# const uint8_t RB0_IMAGE_MODE = 0xda;
# const uint8_t RB0_RSVD193 = 0xdb;
# const uint8_t RB0_RSVD194 = 0xdc;
# const uint8_t RB0_RSVD195 = 0xdd;
# const uint8_t RB0_RSVD196 = 0xde;
# const uint8_t RB0_RSVD197 = 0xdf;
# const uint8_t RB0_RESET = 0xe0;
# const uint8_t RB0_RSVD198 = 0xe1;
# const uint8_t RB0_RSVD199 = 0xe2;
# const uint8_t RB0_RSVD200 = 0xe3;
# const uint8_t RB0_RSVD201 = 0xe4;
# const uint8_t RB0_RSVD202 = 0xe5;
# const uint8_t RB0_RSVD203 = 0xe6;
# const uint8_t RB0_RSVD204 = 0xe7;
# const uint8_t RB0_RSVD205 = 0xe8;
# const uint8_t RB0_RSVD206 = 0xe9;
# const uint8_t RB0_RSVD207 = 0xea;
# const uint8_t RB0_RSVD208 = 0xeb;
# const uint8_t RB0_RSVD209 = 0xec;
# const uint8_t RB0_REGED = 0xed;
# const uint8_t RB0_RSVD211 = 0xee;
# const uint8_t RB0_RSVD212 = 0xef;
# const uint8_t RB0_MS_SP = 0xf0;
# const uint8_t RB0_RSVD213 = 0xf1;
# const uint8_t RB0_RSVD214 = 0xf2;
# const uint8_t RB0_RSVD215 = 0xf3;
# const uint8_t RB0_RSVD216 = 0xf4;
# const uint8_t RB0_RSVD217 = 0xf5;
# const uint8_t RB0_RSVD218 = 0xf6;
# const uint8_t RB0_SS_ID = 0xf7;
# const uint8_t RB0_SS_CTRL = 0xf8;
# const uint8_t RB0_MC_BIST = 0xf9;
# const uint8_t RB0_MC_AL = 0xfa;
# const uint8_t RB0_MC_AH = 0xfb;
# const uint8_t RB0_MC_D = 0xfc;
# const uint8_t RB0_P_CMD = 0xfd;
# const uint8_t RB0_P_STATUS = 0xfe;
# const uint8_t RB0_RA_DLMT = 0xff;
# const uint8_t RB1_GAIN = 0x00;
# const uint8_t RB1_RSVD00 = 0x01;
# const uint8_t RB1_RSVD01 = 0x02;
# const uint8_t RB1_COM1 = 0x03;
# const uint8_t RB1_REG04 = 0x04;
# const uint8_t RB1_RSVD02 = 0x05;
# const uint8_t RB1_RSVD03 = 0x06;
# const uint8_t RB1_RSVD04 = 0x07;
# const uint8_t RB1_REG08 = 0x08;
# const uint8_t RB1_COM2 = 0x09;
# const uint8_t RB1_PIDH = 0x0a;
# const uint8_t RB1_PIDL = 0x0b;
# const uint8_t RB1_COM3 = 0x0c;
# const uint8_t RB1_COM4 = 0x0d;
# const uint8_t RB1_RSVD05 = 0x0e;
# const uint8_t RB1_RSVD06 = 0x0f;
# const uint8_t RB1_AEC = 0x10;
# const uint8_t RB1_CLKRC = 0x11;
# const uint8_t RB1_COM7 = 0x12;
# const uint8_t RB1_COM8 = 0x13;
# const uint8_t RB1_COM9 = 0x14;
# const uint8_t RB1_COM10 = 0x15;
# const uint8_t RB1_RSVD07 = 0x16;
# const uint8_t RB1_HREFST = 0x17;
# const uint8_t RB1_HREFEND = 0x18;
# const uint8_t RB1_VSTRT = 0x19;
# const uint8_t RB1_VEND = 0x1a;
# const uint8_t RB1_RSVD08 = 0x1b;
# const uint8_t RB1_MIDH = 0x1c;
# const uint8_t RB1_MIDL = 0x1d;
# const uint8_t RB1_RSVD09 = 0x1e;
# const uint8_t RB1_RSVD10 = 0x1f;
# const uint8_t RB1_RSVD11 = 0x20;
# const uint8_t RB1_RSVD12 = 0x21;
# const uint8_t RB1_RSVD13 = 0x22;
# const uint8_t RB1_RSVD14 = 0x23;
# const uint8_t RB1_AEW = 0x24;
# const uint8_t RB1_AEB = 0x25;
# const uint8_t RB1_VV = 0x26;
# const uint8_t RB1_RSVD15 = 0x27;
# const uint8_t RB1_RSVD16 = 0x28;
# const uint8_t RB1_RSVD17 = 0x29;
# const uint8_t RB1_REG2A = 0x2a;
# const uint8_t RB1_FRARL = 0x2b;
# const uint8_t RB1_RSVD18 = 0x2c;
# const uint8_t RB1_ADDVSL = 0x2d;
# const uint8_t RB1_ADDVSH = 0x2e;
# const uint8_t RB1_YAVG = 0x2f;
# const uint8_t RB1_HSDY = 0x30;
# const uint8_t RB1_HEDY = 0x31;
# const uint8_t RB1_REG32 = 0x32;
# const uint8_t RB1_RSVD19 = 0x33;
# const uint8_t RB1_ARCOM2 = 0x34;
# const uint8_t RB1_RSVD20 = 0x35;
# const uint8_t RB1_RSVD21 = 0x36;
# const uint8_t RB1_RSVD22 = 0x37;
# const uint8_t RB1_RSVD23 = 0x38;
# const uint8_t RB1_RSVD24 = 0x39;
# const uint8_t RB1_RSVD25 = 0x3a;
# const uint8_t RB1_RSVD26 = 0x3b;
# const uint8_t RB1_RSVD27 = 0x3c;
# const uint8_t RB1_RSVD28 = 0x3d;
# const uint8_t RB1_RSVD29 = 0x3e;
# const uint8_t RB1_RSVD30 = 0x3f;
# const uint8_t RB1_RSVD31 = 0x40;
# const uint8_t RB1_RSVD32 = 0x41;
# const uint8_t RB1_RSVD33 = 0x42;
# const uint8_t RB1_RSVD34 = 0x43;
# const uint8_t RB1_RSVD35 = 0x44;
# const uint8_t RB1_REG45 = 0x45;
# const uint8_t RB1_FLL = 0x46;
# const uint8_t RB1_FLH = 0x47;
# const uint8_t RB1_COM19 = 0x48;
# const uint8_t RB1_ZOOMS = 0x49;
# const uint8_t RB1_RSVD36 = 0x4a;
# const uint8_t RB1_COM22 = 0x4b;
# const uint8_t RB1_RSVD37 = 0x4c;
# const uint8_t RB1_RSVD38 = 0x4d;
# const uint8_t RB1_COM25 = 0x4e;
# const uint8_t RB1_BD50 = 0x4f;
# const uint8_t RB1_BD60 = 0x50;
# const uint8_t RB1_RSVD39 = 0x51;
# const uint8_t RB1_RSVD40 = 0x52;
# const uint8_t RB1_RSVD41 = 0x53;
# const uint8_t RB1_RSVD42 = 0x54;
# const uint8_t RB1_RSVD43 = 0x55;
# const uint8_t RB1_RSVD44 = 0x56;
# const uint8_t RB1_RSVD45 = 0x57;
# const uint8_t RB1_RSVD46 = 0x58;
# const uint8_t RB1_RSVD47 = 0x59;
# const uint8_t RB1_RSVD48 = 0x5a;
# const uint8_t RB1_RSVD49 = 0x5b;
# const uint8_t RB1_RSVD50 = 0x5c;
# const uint8_t RB1_REG5D = 0x5d;
# const uint8_t RB1_REG5E = 0x5e;
# const uint8_t RB1_REG5F = 0x5f;
# const uint8_t RB1_REG60 = 0x60;
# const uint8_t RB1_HISTO_LOW = 0x61;
# const uint8_t RB1_HISTO_HIGH = 0x62;
# const uint8_t RB1_RSVD51 = 0x63;
# const uint8_t RB1_RSVD52 = 0x64;
# const uint8_t RB1_RSVD53 = 0x65;
# const uint8_t RB1_RSVD54 = 0x66;
# const uint8_t RB1_RSVD55 = 0x67;
# const uint8_t RB1_RSVD56 = 0x68;
# const uint8_t RB1_RSVD57 = 0x69;
# const uint8_t RB1_RSVD58 = 0x6a;
# const uint8_t RB1_RSVD59 = 0x6b;
# const uint8_t RB1_RSVD60 = 0x6c;
# const uint8_t RB1_RSVD61 = 0x6d;
# const uint8_t RB1_RSVD62 = 0x6e;
# const uint8_t RB1_RSVD63 = 0x6f;
# const uint8_t RB1_RSVD64 = 0x70;
# const uint8_t RB1_RSVD65 = 0x71;
# const uint8_t RB1_RSVD66 = 0x72;
# const uint8_t RB1_RSVD67 = 0x73;
# const uint8_t RB1_RSVD68 = 0x74;
# const uint8_t RB1_RSVD69 = 0x75;
# const uint8_t RB1_RSVD70 = 0x76;
# const uint8_t RB1_RSVD71 = 0x77;
# const uint8_t RB1_RSVD72 = 0x78;
# const uint8_t RB1_RSVD73 = 0x79;
# const uint8_t RB1_RSVD74 = 0x7a;
# const uint8_t RB1_RSVD75 = 0x7b;
# const uint8_t RB1_RSVD76 = 0x7c;
# const uint8_t RB1_RSVD77 = 0x7d;
# const uint8_t RB1_RSVD78 = 0x7e;
# const uint8_t RB1_RSVD79 = 0x7f;
# const uint8_t RB1_RSVD80 = 0x80;
# const uint8_t RB1_RSVD81 = 0x81;
# const uint8_t RB1_RSVD82 = 0x82;
# const uint8_t RB1_RSVD83 = 0x83;
# const uint8_t RB1_RSVD84 = 0x84;
# const uint8_t RB1_RSVD85 = 0x85;
# const uint8_t RB1_RSVD86 = 0x86;
# const uint8_t RB1_RSVD87 = 0x87;
# const uint8_t RB1_RSVD88 = 0x88;
# const uint8_t RB1_RSVD89 = 0x89;
# const uint8_t RB1_RSVD90 = 0x8a;
# const uint8_t RB1_RSVD91 = 0x8b;
# const uint8_t RB1_RSVD92 = 0x8c;
# const uint8_t RB1_RSVD93 = 0x8d;
# const uint8_t RB1_RSVD94 = 0x8e;
# const uint8_t RB1_RSVD95 = 0x8f;
# const uint8_t RB1_RSVD96 = 0x90;
# const uint8_t RB1_RSVD97 = 0x91;
# const uint8_t RB1_RSVD98 = 0x92;
# const uint8_t RB1_RSVD99 = 0x93;
# const uint8_t RB1_RSVD100 = 0x94;
# const uint8_t RB1_RSVD101 = 0x95;
# const uint8_t RB1_RSVD102 = 0x96;
# const uint8_t RB1_RSVD103 = 0x97;
# const uint8_t RB1_RSVD104 = 0x98;
# const uint8_t RB1_RSVD105 = 0x99;
# const uint8_t RB1_RSVD106 = 0x9a;
# const uint8_t RB1_RSVD107 = 0x9b;
# const uint8_t RB1_RSVD108 = 0x9c;
# const uint8_t RB1_RSVD109 = 0x9d;
# const uint8_t RB1_RSVD110 = 0x9e;
# const uint8_t RB1_RSVD111 = 0x9f;
# const uint8_t RB1_RSVD112 = 0xa0;
# const uint8_t RB1_RSVD113 = 0xa1;
# const uint8_t RB1_RSVD114 = 0xa2;
# const uint8_t RB1_RSVD115 = 0xa3;
# const uint8_t RB1_RSVD116 = 0xa4;
# const uint8_t RB1_RSVD117 = 0xa5;
# const uint8_t RB1_RSVD118 = 0xa6;
# const uint8_t RB1_RSVD119 = 0xa7;
# const uint8_t RB1_RSVD120 = 0xa8;
# const uint8_t RB1_RSVD121 = 0xa9;
# const uint8_t RB1_RSVD122 = 0xaa;
# const uint8_t RB1_RSVD123 = 0xab;
# const uint8_t RB1_RSVD124 = 0xac;
# const uint8_t RB1_RSVD125 = 0xad;
# const uint8_t RB1_RSVD126 = 0xae;
# const uint8_t RB1_RSVD127 = 0xaf;
# const uint8_t RB1_RSVD128 = 0xb0;
# const uint8_t RB1_RSVD129 = 0xb1;
# const uint8_t RB1_RSVD130 = 0xb2;
# const uint8_t RB1_RSVD131 = 0xb3;
# const uint8_t RB1_RSVD132 = 0xb4;
# const uint8_t RB1_RSVD133 = 0xb5;
# const uint8_t RB1_RSVD134 = 0xb6;
# const uint8_t RB1_RSVD135 = 0xb7;
# const uint8_t RB1_RSVD136 = 0xb8;
# const uint8_t RB1_RSVD137 = 0xb9;
# const uint8_t RB1_RSVD138 = 0xba;
# const uint8_t RB1_RSVD139 = 0xbb;
# const uint8_t RB1_RSVD140 = 0xbc;
# const uint8_t RB1_RSVD141 = 0xbd;
# const uint8_t RB1_RSVD142 = 0xbe;
# const uint8_t RB1_RSVD143 = 0xbf;
# const uint8_t RB1_RSVD144 = 0xc0;
# const uint8_t RB1_RSVD145 = 0xc1;
# const uint8_t RB1_RSVD146 = 0xc2;
# const uint8_t RB1_RSVD147 = 0xc3;
# const uint8_t RB1_RSVD148 = 0xc4;
# const uint8_t RB1_RSVD149 = 0xc5;
# const uint8_t RB1_RSVD150 = 0xc6;
# const uint8_t RB1_RSVD151 = 0xc7;
# const uint8_t RB1_RSVD152 = 0xc8;
# const uint8_t RB1_RSVD153 = 0xc9;
# const uint8_t RB1_RSVD154 = 0xca;
# const uint8_t RB1_RSVD155 = 0xcb;
# const uint8_t RB1_RSVD156 = 0xcc;
# const uint8_t RB1_RSVD157 = 0xcd;
# const uint8_t RB1_RSVD158 = 0xce;
# const uint8_t RB1_RSVD159 = 0xcf;
# const uint8_t RB1_RSVD160 = 0xd0;
# const uint8_t RB1_RSVD161 = 0xd1;
# const uint8_t RB1_RSVD162 = 0xd2;
# const uint8_t RB1_RSVD163 = 0xd3;
# const uint8_t RB1_RSVD164 = 0xd4;
# const uint8_t RB1_RSVD165 = 0xd5;
# const uint8_t RB1_RSVD166 = 0xd6;
# const uint8_t RB1_RSVD167 = 0xd7;
# const uint8_t RB1_RSVD168 = 0xd8;
# const uint8_t RB1_RSVD169 = 0xd9;
# const uint8_t RB1_RSVD170 = 0xda;
# const uint8_t RB1_RSVD171 = 0xdb;
# const uint8_t RB1_RSVD172 = 0xdc;
# const uint8_t RB1_RSVD173 = 0xdd;
# const uint8_t RB1_RSVD174 = 0xde;
# const uint8_t RB1_RSVD175 = 0xdf;
# const uint8_t RB1_RSVD176 = 0xe0;
# const uint8_t RB1_RSVD177 = 0xe1;
# const uint8_t RB1_RSVD178 = 0xe2;
# const uint8_t RB1_RSVD179 = 0xe3;
# const uint8_t RB1_RSVD180 = 0xe4;
# const uint8_t RB1_RSVD181 = 0xe5;
# const uint8_t RB1_RSVD182 = 0xe6;
# const uint8_t RB1_RSVD183 = 0xe7;
# const uint8_t RB1_RSVD184 = 0xe8;
# const uint8_t RB1_RSVD185 = 0xe9;
# const uint8_t RB1_RSVD186 = 0xea;
# const uint8_t RB1_RSVD187 = 0xeb;
# const uint8_t RB1_RSVD188 = 0xec;
# const uint8_t RB1_RSVD189 = 0xed;
# const uint8_t RB1_RSVD190 = 0xee;
# const uint8_t RB1_RSVD191 = 0xef;
# const uint8_t RB1_RSVD192 = 0xf0;
# const uint8_t RB1_RSVD193 = 0xf1;
# const uint8_t RB1_RSVD194 = 0xf2;
# const uint8_t RB1_RSVD195 = 0xf3;
# const uint8_t RB1_RSVD196 = 0xf4;
# const uint8_t RB1_RSVD197 = 0xf5;
# const uint8_t RB1_RSVD198 = 0xf6;
# const uint8_t RB1_RSVD199 = 0xf7;
# const uint8_t RB1_RSVD200 = 0xf8;
# const uint8_t RB1_RSVD201 = 0xf9;
# const uint8_t RB1_RSVD202 = 0xfa;
# const uint8_t RB1_RSVD203 = 0xfb;
# const uint8_t RB1_RSVD204 = 0xfc;
# const uint8_t RB1_RSVD205 = 0xfd;
# const uint8_t RB1_RSVD206 = 0xfe;
# const uint8_t RB1_RSVD207 = 0xff;

# %%
types = {"[7:0]": "BYTE","[3:0]":"NIBBLE","[1:0]":"BIT"}


OV2640Program.loadRegisters()
#OV2640Program.printRegisters()
pgm = OV2640Program();
#pgm.compile('OV2640_QVGA')
pgm.compile('OV2640_JPEG_INIT')
pgm.compile('OV2640_YUV422')
pgm.compile('OV2640_JPEG')
pgm.compile('OV2640_160x120_JPEG')
pgm.compile('OV2640_176x144_JPEG')
pgm.compile('OV2640_320x240_JPEG')
pgm.compile('OV2640_352x288_JPEG')
pgm.compile('OV2640_640x480_JPEG')
pgm.compile('OV2640_800x600_JPEG')
pgm.compile('OV2640_1024x768_JPEG')
pgm.compile('OV2640_1280x1024_JPEG')
pgm.compile('OV2640_1600x1200_JPEG')
# Out:
# Compiling OV2640_JPEG_INIT
# const uint8_t[] OV2640_JPEG_INIT {
# 	RB0_RA_DLMT,DSP,
# 	RB0_RSVD43,0xff,
# 	RB0_RSVD45,0xdf,
# 	RB0_RA_DLMT,SENS,
# 	RB1_RSVD27,0x32,
# 	RB1_CLKRC,0x04,
# 	RB1_COM2,0x02,
# 	RB1_REG04,0x28,
# 	RB1_COM8,DEF | BNDF_EN | AGC_EN | AEC_EN,
# 	RB1_COM9,AGC_GAIN_8x,
# 	RB1_RSVD18,0x0c,
# 	RB1_RSVD19,0x78,
# 	RB1_RSVD25,0x33,
# 	RB1_RSVD26,0xfb,
# 	RB1_RSVD29,0x00,
# 	RB1_RSVD34,0x11,
# 	RB1_RSVD07,0x10,
# 	RB1_RSVD24,0x92,
# 	RB1_RSVD20,0xda,
# 	RB1_RSVD13,0x1a,
# 	RB1_RSVD22,0xc3,
# 	RB1_RSVD14,0x00,
# 	RB1_ARCOM2,0xc0,
# 	RB1_RSVD21,0x1a,
# 	RB1_RSVD03,0x88,
# 	RB1_RSVD04,0xc0,
# 	RB1_COM4,0x87,
# 	RB1_RSVD05,0x41,
# 	RB1_RSVD37,0x00,
# 	RB1_COM19,0x00,
# 	RB1_RSVD49,0x00,
# 	RB1_RSVD33,0x03,
# 	RB1_RSVD36,0x81,
# 	RB1_RSVD12,0x99,
# 	RB1_AEW,0x40,
# 	RB1_AEB,0x38,
# 	RB1_VV,0x82,
# 	RB1_RSVD50,0x00,
# 	RB1_RSVD51,0x00,
# 	RB1_HISTO_LOW,0x70,
# 	RB1_HISTO_HIGH,0x80,
# 	RB1_RSVD76,0x05,
# 	RB1_RSVD11,0x80,
# 	RB1_RSVD16,0x30,
# 	RB1_RSVD60,0x00,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD62,0x00,
# 	RB1_RSVD64,0x02,
# 	RB1_RSVD65,0x94,
# 	RB1_RSVD67,0xc1,
# 	RB1_COM7,RES_SVGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x43,
# 	RB1_VSTRT,0x00,
# 	RB1_VEND,0x4b,
# 	RB1_REG32,0x09,
# 	RB1_RSVD22,0xc0,
# 	RB1_BD50,0x60,
# 	RB1_BD60,0xa8,
# 	RB1_RSVD61,0x00,
# 	RB1_RSVD28,0x38,
# 	RB1_FLL,0x3f,
# 	RB1_BD50,0x60,
# 	RB1_COM3,BAND_50H,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RSVD202,0x7f,
# 	RB0_MC_BIST,RESET | BOOT_ROM_SEL,
# 	RB0_RSVD64,0x24,
# 	RB0_RESET,JPEG | DVP,
# 	RB0_RSVD103,0xff,
# 	RB0_RSVD50,0xa0,
# 	RB0_RSVD65,0x20,
# 	RB0_RSVD66,0x18,
# 	RB0_RSVD74,0x00,
# 	RB0_CTRL3,BPC_EN | WPC_EN,
# 	RB0_RSVD117,0x3f,
# 	RB0_RSVD190,0x03,
# 	RB0_RSVD192,0x10,
# 	RB0_R_DVP_SP,SP_AUTO_MODE,
# 	RB0_RSVD176,0x08,
# 	RB0_RSVD177,0x80,
# 	RB0_BPADDR,0x00,
# 	RB0_BPDATA,0x00,
# 	RB0_BPADDR,0x03,
# 	RB0_BPDATA,0x48,
# 	RB0_BPDATA,0x48,
# 	RB0_BPADDR,0x08,
# 	RB0_BPDATA,0x20,
# 	RB0_BPDATA,0x10,
# 	RB0_BPDATA,0x0e,
# 	RB0_RSVD124,0x00,
# 	RB0_RSVD125,0x0e,
# 	RB0_RSVD125,0x1a,
# 	RB0_RSVD125,0x31,
# 	RB0_RSVD125,0x5a,
# 	RB0_RSVD125,0x69,
# 	RB0_RSVD125,0x75,
# 	RB0_RSVD125,0x7e,
# 	RB0_RSVD125,0x88,
# 	RB0_RSVD125,0x8f,
# 	RB0_RSVD125,0x96,
# 	RB0_RSVD125,0xa3,
# 	RB0_RSVD125,0xaf,
# 	RB0_RSVD125,0xc4,
# 	RB0_RSVD125,0xd7,
# 	RB0_RSVD125,0xe8,
# 	RB0_RSVD125,0x20,
# 	RB0_RSVD126,0x00,
# 	RB0_RSVD127,0x06,
# 	RB0_RSVD127,0xe3,
# 	RB0_RSVD127,0x05,
# 	RB0_RSVD127,0x05,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x04,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD127,0x00,
# 	RB0_RSVD130,0x00,
# 	RB0_RSVD131,0x08,
# 	RB0_RSVD131,0x19,
# 	RB0_RSVD131,0x02,
# 	RB0_RSVD131,0x0c,
# 	RB0_RSVD131,0x24,
# 	RB0_RSVD131,0x30,
# 	RB0_RSVD131,0x28,
# 	RB0_RSVD131,0x26,
# 	RB0_RSVD131,0x02,
# 	RB0_RSVD131,0x98,
# 	RB0_RSVD131,0x80,
# 	RB0_RSVD131,0x00,
# 	RB0_RSVD131,0x00,
# 	RB0_CTRL1,CIP | DMY | RAW_GMA | AWB | AWB_GAIN | PRE,
# 	RB0_RSVD144,0x00,
# 	RB0_RSVD148,0x00,
# 	RB0_RSVD173,0x11,
# 	RB0_RSVD174,0x51,
# 	RB0_RSVD171,0x80,
# 	RB0_RSVD175,0x10,
# 	RB0_RSVD162,0x66,
# 	RB0_RSVD164,0xa5,
# 	RB0_RSVD163,0x64,
# 	RB0_RSVD165,0x7c,
# 	RB0_RSVD159,0xaf,
# 	RB0_RSVD160,0x97,
# 	RB0_RSVD161,0xff,
# 	RB0_RSVD156,0xc5,
# 	RB0_RSVD157,0x94,
# 	RB0_RSVD158,0x0f,
# 	RB0_RSVD172,0x5c,
# 	RB0_HSIZE8,0x64,
# 	RB0_VSIZE8,0x4b,
# 	RB0_SIZEL,0x00,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x00,
# 	RB0_HSIZE,0xc8,
# 	RB0_VSIZE,0x96,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_ZMOW,0xc8,
# 	RB0_ZMOH,0x96,
# 	RB0_ZMHH,0x00,
# 	RB0_R_DVP_SP,0x00,
# 	RB0_CTRL1,CIP | DMY | RAW_GMA | AWB | AWB_GAIN | PRE,
# 	RB0_RSVD110,0x00,
# 	RB0_IMAGE_MODE,YUV422,
# 	RB0_RSVD202,0x1f,
# 	RB0_RSVD198,0x67,
# 	RB0_RESET,0x00,
# 	RB0_RSVD195,0x7f,
# 	RB0_R_BYPASS,USE_DSP,
# 	RB0_RSVD17,0x40,
# 	RB0_R_DVP_SP,0x04,
# 	RB0_HSIZE8,0x16,
# 	RB0_VSIZE8,0x12,
# 	RB0_SIZEL,0x00,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x00,
# 	RB0_HSIZE,0x2c,
# 	RB0_VSIZE,0x24,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_ZMOW,0x2c,
# 	RB0_ZMOH,0x24,
# 	RB0_ZMHH,0x00,
# };
# Compiling OV2640_YUV422
# const uint8_t[] OV2640_YUV422 {
# 	RB0_RA_DLMT,DSP,
# 	RB0_R_BYPASS,USE_DSP,
# 	RB0_IMAGE_MODE,JPEG_EN,
# 	RB0_RSVD190,0x03,
# 	RB0_RSVD197,0x00,
# 	RB0_RSVD50,0x80,
# 	RB0_RSVD59,0x40,
# 	RB0_RSVD198,0x77,
# 	RB0_RSVD00,0x00,
# };
# Compiling OV2640_JPEG
# const uint8_t[] OV2640_JPEG {
# 	0xe0,0x14,
# 	0xe1,0x77,
# 	0xe5,0x1f,
# 	0xd7,0x03,
# 	0xda,0x10,
# 	0xe0,0x00,
# 	RB0_RA_DLMT,SENS,
# 	RB1_REG04,0x08,
# };
# Compiling OV2640_160x120_JPEG
# const uint8_t[] OV2640_160x120_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_COM7,RES_SVGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x43,
# 	RB1_VSTRT,0x00,
# 	RB1_VEND,0x4b,
# 	RB1_REG32,0x09,
# 	RB1_BD50,0xca,
# 	RB1_BD60,0xa8,
# 	RB1_RSVD48,0x23,
# 	RB1_RSVD61,0x00,
# 	RB1_RSVD24,0x12,
# 	RB1_RSVD20,0xda,
# 	RB1_RSVD13,0x1a,
# 	RB1_RSVD22,0xc3,
# 	RB1_RSVD14,0x00,
# 	RB1_ARCOM2,0xc0,
# 	RB1_RSVD21,0x1a,
# 	RB1_RSVD03,0x88,
# 	RB1_RSVD04,0xc0,
# 	RB1_COM4,0x87,
# 	RB1_RSVD05,0x41,
# 	RB1_RSVD37,0x00,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0x64,
# 	RB0_VSIZE8,0x4b,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x92,
# 	RB0_HSIZE,0xc8,
# 	RB0_VSIZE,0x96,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x28,
# 	RB0_ZMOH,0x1e,
# 	RB0_ZMHH,0x00,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_176x144_JPEG
# const uint8_t[] OV2640_176x144_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_COM7,RES_SVGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x43,
# 	RB1_VSTRT,0x00,
# 	RB1_VEND,0x4b,
# 	RB1_REG32,0x09,
# 	RB1_BD50,0xca,
# 	RB1_BD60,0xa8,
# 	RB1_RSVD48,0x23,
# 	RB1_RSVD61,0x00,
# 	RB1_RSVD24,0x12,
# 	RB1_RSVD20,0xda,
# 	RB1_RSVD13,0x1a,
# 	RB1_RSVD22,0xc3,
# 	RB1_RSVD14,0x00,
# 	RB1_ARCOM2,0xc0,
# 	RB1_RSVD21,0x1a,
# 	RB1_RSVD03,0x88,
# 	RB1_RSVD04,0xc0,
# 	RB1_COM4,0x87,
# 	RB1_RSVD05,0x41,
# 	RB1_RSVD37,0x00,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0x64,
# 	RB0_VSIZE8,0x4b,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x92,
# 	RB0_HSIZE,0xc8,
# 	RB0_VSIZE,0x96,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x2c,
# 	RB0_ZMOH,0x24,
# 	RB0_ZMHH,0x00,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_320x240_JPEG
# const uint8_t[] OV2640_320x240_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_COM7,RES_SVGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x43,
# 	RB1_VSTRT,0x00,
# 	RB1_VEND,0x4b,
# 	RB1_REG32,0x09,
# 	RB1_BD50,0xca,
# 	RB1_BD60,0xa8,
# 	RB1_RSVD48,0x23,
# 	RB1_RSVD61,0x00,
# 	RB1_RSVD24,0x12,
# 	RB1_RSVD20,0xda,
# 	RB1_RSVD13,0x1a,
# 	RB1_RSVD22,0xc3,
# 	RB1_RSVD14,0x00,
# 	RB1_ARCOM2,0xc0,
# 	RB1_RSVD21,0x1a,
# 	RB1_RSVD03,0x88,
# 	RB1_RSVD04,0xc0,
# 	RB1_COM4,0x87,
# 	RB1_RSVD05,0x41,
# 	RB1_RSVD37,0x00,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0x64,
# 	RB0_VSIZE8,0x4b,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x89,
# 	RB0_HSIZE,0xc8,
# 	RB0_VSIZE,0x96,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x50,
# 	RB0_ZMOH,0x3c,
# 	RB0_ZMHH,0x00,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_352x288_JPEG
# const uint8_t[] OV2640_352x288_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_COM7,RES_SVGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x43,
# 	RB1_VSTRT,0x00,
# 	RB1_VEND,0x4b,
# 	RB1_REG32,0x09,
# 	RB1_BD50,0xca,
# 	RB1_BD60,0xa8,
# 	RB1_RSVD48,0x23,
# 	RB1_RSVD61,0x00,
# 	RB1_RSVD24,0x12,
# 	RB1_RSVD20,0xda,
# 	RB1_RSVD13,0x1a,
# 	RB1_RSVD22,0xc3,
# 	RB1_RSVD14,0x00,
# 	RB1_ARCOM2,0xc0,
# 	RB1_RSVD21,0x1a,
# 	RB1_RSVD03,0x88,
# 	RB1_RSVD04,0xc0,
# 	RB1_COM4,0x87,
# 	RB1_RSVD05,0x41,
# 	RB1_RSVD37,0x00,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0x64,
# 	RB0_VSIZE8,0x4b,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x89,
# 	RB0_HSIZE,0xc8,
# 	RB0_VSIZE,0x96,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x00,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x58,
# 	RB0_ZMOH,0x48,
# 	RB0_ZMHH,0x00,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_640x480_JPEG
# const uint8_t[] OV2640_640x480_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_CLKRC,0x01,
# 	RB1_COM7,RES_UXGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x75,
# 	RB1_REG32,0x36,
# 	RB1_VSTRT,0x01,
# 	RB1_VEND,0x97,
# 	RB1_COM1,VWIN_LSB_UXGA | VWIN_LSB_SVGA | VWIN_LSB_CIF,
# 	RB1_RSVD22,0x40,
# 	RB1_BD50,0xbb,
# 	RB1_BD60,0x9c,
# 	RB1_RSVD48,0x57,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD28,0x34,
# 	RB1_RSVD24,0x02,
# 	RB1_RSVD20,0x88,
# 	RB1_RSVD13,0x0a,
# 	RB1_RSVD22,0x40,
# 	RB1_ARCOM2,0xa0,
# 	RB1_RSVD03,0x02,
# 	RB1_COM4,0xb7,
# 	RB1_RSVD05,0x01,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0xc8,
# 	RB0_VSIZE8,0x96,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x89,
# 	RB0_HSIZE,0x90,
# 	RB0_VSIZE,0x2c,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x88,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0xa0,
# 	RB0_ZMOH,0x78,
# 	RB0_ZMHH,0x00,
# 	RB0_R_DVP_SP,0x04,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_800x600_JPEG
# const uint8_t[] OV2640_800x600_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_CLKRC,0x01,
# 	RB1_COM7,RES_UXGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x75,
# 	RB1_REG32,0x36,
# 	RB1_VSTRT,0x01,
# 	RB1_VEND,0x97,
# 	RB1_COM1,VWIN_LSB_UXGA | VWIN_LSB_SVGA | VWIN_LSB_CIF,
# 	RB1_RSVD22,0x40,
# 	RB1_BD50,0xbb,
# 	RB1_BD60,0x9c,
# 	RB1_RSVD48,0x57,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD28,0x34,
# 	RB1_RSVD24,0x02,
# 	RB1_RSVD20,0x88,
# 	RB1_RSVD13,0x0a,
# 	RB1_RSVD22,0x40,
# 	RB1_ARCOM2,0xa0,
# 	RB1_RSVD03,0x02,
# 	RB1_COM4,0xb7,
# 	RB1_RSVD05,0x01,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0xc8,
# 	RB0_VSIZE8,0x96,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x89,
# 	RB0_HSIZE,0x90,
# 	RB0_VSIZE,0x2c,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x88,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0xc8,
# 	RB0_ZMOH,0x96,
# 	RB0_ZMHH,0x00,
# 	RB0_R_DVP_SP,0x02,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_1024x768_JPEG
# const uint8_t[] OV2640_1024x768_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_CLKRC,0x01,
# 	RB1_COM7,RES_UXGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x75,
# 	RB1_REG32,0x36,
# 	RB1_VSTRT,0x01,
# 	RB1_VEND,0x97,
# 	RB1_COM1,VWIN_LSB_UXGA | VWIN_LSB_SVGA | VWIN_LSB_CIF,
# 	RB1_RSVD22,0x40,
# 	RB1_BD50,0xbb,
# 	RB1_BD60,0x9c,
# 	RB1_RSVD48,0x57,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD28,0x34,
# 	RB1_RSVD24,0x02,
# 	RB1_RSVD20,0x88,
# 	RB1_RSVD13,0x0a,
# 	RB1_RSVD22,0x40,
# 	RB1_ARCOM2,0xa0,
# 	RB1_RSVD03,0x02,
# 	RB1_COM4,0xb7,
# 	RB1_RSVD05,0x01,
# 	RB0_RA_DLMT,DSP,
# 	RB0_HSIZE8,0xc8,
# 	RB0_VSIZE8,0x96,
# 	RB0_SIZEL,0x00,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x00,
# 	RB0_HSIZE,0x90,
# 	RB0_VSIZE,0x2c,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x88,
# 	RB0_ZMOW,0x00,
# 	RB0_ZMOH,0xc0,
# 	RB0_ZMHH,0x01,
# 	RB0_R_DVP_SP,0x02,
# };
# Compiling OV2640_1280x1024_JPEG
# const uint8_t[] OV2640_1280x1024_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_CLKRC,0x01,
# 	RB1_COM7,RES_UXGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x75,
# 	RB1_REG32,0x36,
# 	RB1_VSTRT,0x01,
# 	RB1_VEND,0x97,
# 	RB1_COM1,VWIN_LSB_UXGA | VWIN_LSB_SVGA | VWIN_LSB_CIF,
# 	RB1_RSVD22,0x40,
# 	RB1_BD50,0xbb,
# 	RB1_BD60,0x9c,
# 	RB1_RSVD48,0x57,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD28,0x34,
# 	RB1_RSVD24,0x02,
# 	RB1_RSVD20,0x88,
# 	RB1_RSVD13,0x0a,
# 	RB1_RSVD22,0x40,
# 	RB1_ARCOM2,0xa0,
# 	RB1_RSVD03,0x02,
# 	RB1_COM4,0xb7,
# 	RB1_RSVD05,0x01,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0xc8,
# 	RB0_VSIZE8,0x96,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x00,
# 	RB0_HSIZE,0x90,
# 	RB0_VSIZE,0x2c,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x88,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x40,
# 	RB0_ZMOH,0xf0,
# 	RB0_ZMHH,0x01,
# 	RB0_R_DVP_SP,0x02,
# 	RB0_RESET,0x00,
# };
# Compiling OV2640_1600x1200_JPEG
# const uint8_t[] OV2640_1600x1200_JPEG {
# 	RB0_RA_DLMT,SENS,
# 	RB1_CLKRC,0x01,
# 	RB1_COM7,RES_UXGA,
# 	RB1_HREFST,0x11,
# 	RB1_HREFEND,0x75,
# 	RB1_REG32,0x36,
# 	RB1_VSTRT,0x01,
# 	RB1_VEND,0x97,
# 	RB1_COM1,VWIN_LSB_UXGA | VWIN_LSB_SVGA | VWIN_LSB_CIF,
# 	RB1_RSVD22,0x40,
# 	RB1_BD50,0xbb,
# 	RB1_BD60,0x9c,
# 	RB1_RSVD48,0x57,
# 	RB1_RSVD61,0x80,
# 	RB1_RSVD28,0x34,
# 	RB1_RSVD24,0x02,
# 	RB1_RSVD20,0x88,
# 	RB1_RSVD13,0x0a,
# 	RB1_RSVD22,0x40,
# 	RB1_ARCOM2,0xa0,
# 	RB1_RSVD03,0x02,
# 	RB1_COM4,0xb7,
# 	RB1_RSVD05,0x01,
# 	RB0_RA_DLMT,DSP,
# 	RB0_RESET,DVP,
# 	RB0_HSIZE8,0xc8,
# 	RB0_VSIZE8,0x96,
# 	RB0_CTRL2,DCW_EN | SDE_EN | UV_ADJ_EN | UV_AVG_EN | CMX_EN,
# 	RB0_CTRL,0x00,
# 	RB0_HSIZE,0x90,
# 	RB0_VSIZE,0x2c,
# 	RB0_XOFFL,0x00,
# 	RB0_YOFFL,0x00,
# 	RB0_VHYX,0x88,
# 	RB0_TEST,0x00,
# 	RB0_ZMOW,0x90,
# 	RB0_ZMOH,0x2c,
# 	RB0_ZMHH,0x05,
# 	RB0_R_DVP_SP,0x02,
# 	RB0_RESET,0x00,
# };

# %%
OV2640Program.loadRegisters()
# Out:
# bitfields = 0
# DSP_BYPAS
# USE_DSP
# bitfields = 2
# bitfields = 0
# bitfields = 0
# bitfields = 0
# LP_DP
# ROUND
# V_DIV_SET(x)
# H_DIV_SET(x)
# bitfields = 4
# SET(x)
# bitfields = 1
# SET(x)
# bitfields = 1
# bitfields = 0
# SET(x)
# bitfields = 1
# VSIZE_SET(x)
# HSIZE_SET(x)
# YOFF_SET(x)
# XOFF_SET(x)
# bitfields = 4
# bitfields = 0
# HSIZE_SET(x)
# bitfields = 1
# OUTW_SET(x)
# bitfields = 1
# OUTH_SET(x)
# bitfields = 1
# ZSPEED_SET(x)
# OUTH_SET(x)
# OUTW_SET(x)VAL_SET(x, 0x3, (8+2), 0)
# bitfields = 3
# bitfields = 0
# bitfields = 0
# bitfields = 0
# bitfields = 0
# DCW_EN
# SDE_EN
# UV_ADJ_EN
# UV_AVG_EN
# CMX_EN
# bitfields = 5
# BPC_EN
# WPC_EN
# bitfields = 2
# bitfields = 0
# HSIZE8_11_SET(x)
# HSIZE8_SET(x)
# VSIZE8_SET(x)
# bitfields = 3
# bitfields = 0
# SET(x)
# bitfields = 1
# SET(x)
# bitfields = 1
# AEC_EN
# AEC_SEL
# STAT_SEL
# VFIRST
# YUV422
# YUV_EN
# RGB_EN
# RAW_EN
# bitfields = 8
# CIP
# DMY
# RAW_GMA
# DG
# AWB
# AWB_GAIN
# LENC
# PRE
# bitfields = 8
# bitfields = 0
# SP_AUTO_MODE
# SP_DVP_MASK
# bitfields = 2
# bitfields = 0
# Y8_DVP_EN
# JPEG_EN
# YUV422
# RAW10
# RGB565
# HREF_VSYNC
# LBYTE_FIRST
# bitfields = 7
# bitfields = 0
# MICROC
# SCCB
# JPEG
# DVP
# IPU
# CIF
# bitfields = 6
# bitfields = 0
# CLK_OUT_DIS
# bitfields = 1
# bitfields = 0
# bitfields = 0
# bitfields = 0
# ADD_AUTO_INC
# CTRL_EN
# DELAY_CLK
# ACC_EN
# SEN_PASS_THR
# bitfields = 5
# RESET
# BOOT_ROM_SEL
# 12KB_SEL
# 12KB_MASK
# 512KB_SEL
# 512KB_MASK
# BUSY_BIT_R
# MC_RES_ONE_SH_W
# LAUNCH
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-37-9cc821b21d65> in <module>()
# ----> 1 OV2640Program.loadRegisters()
#
# <ipython-input-36-70b907232f40> in loadRegisters()
#      55                     fieldIndex = 6
#      56                     bfc = 0
# ---> 57                     while len(row[fieldIndex]) > 0:
#      58                         print(row[fieldIndex])
#      59                         bitfields.append(OV2640BitField(row[fieldIndex],row[fieldIndex + 1],row[fieldIndex + 2]))
#
# IndexError: list index out of range
